# %% [markdown]
# * [1.Load Data From CSV File](#ld)
# * [2.Build a pipeline](#bp)
# * [3.Idée pour choisir le meilleur modèle](#ic)
# * [4.Modèles de machine learning choisis](#mml)

# %%
#!pip install xgboost

# %%
#!pip install lightgbm

# %%
#!pip install shap

# %%
import pandas as pd
import numpy as np

import missingno as msno
import seaborn as sns

import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import OneHotEncoder,StandardScaler

from sklearn.compose import make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.dummy import DummyRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from  xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
import joblib
import shap

import sklearn

from sklearn.metrics import confusion_matrix

from sklearn.model_selection import train_test_split, GridSearchCV,cross_val_score,StratifiedGroupKFold
from sklearn.metrics import mean_absolute_error,r2_score
from time import time


from sklearn.metrics import mean_squared_error
warnings.filterwarnings('ignore')

# %%
############Fonction affichant les variables corrélés en fixant un seuil
def f_strong_correlation(threshold_up ,df2):
    #threshold_up = 0.7
    corr_pairs = df2.corr().unstack().sort_values(kind="quicksort")
    strong_corr = (pd.DataFrame(corr_pairs[(abs(corr_pairs) > threshold_up)])
               .reset_index().rename(columns={0:'corr_coeff'}))
    strong_corr = strong_corr[(strong_corr.index%2 == 0) & 
                          (strong_corr['level_0'] != strong_corr['level_1'])]
    strong_corr.sort_values('corr_coeff', ascending=False)
    return strong_corr
##################"fonction pour afficher les performances d'un modèle
def f_performance(pip):
    #pip.fit(X_train,y_train)
  
    
    print('******************')
    #Check MSE and RMSE

    y_pred = pip.predict(X_test)
    print(f'MSE : {mean_squared_error(y_test, y_pred):.3f}')
    print(f'RMSE : {np.sqrt(mean_squared_error(y_test, y_pred)):.3f}')
    print(f'R2 : {r2_score(y_test, y_pred):.3f}')
##################################################
def f_coeff(pip):
    # Putting together the coefficient and their corresponding variable names
    
    df_coefficient = pd.DataFrame()
    df_coefficient["Columns"] = feature_after_transformer(preprocessor)
    df_coefficient['Estimated Coefficient '] = pd.Series(pip.named_steps['model'].coef_.flatten())
    return df_coefficient
    #print(lreg_coefficient)
####################""
def feature_after_transformer(preprocessor):
    tx = preprocessor.get_params()['transformers']
    feature_names = []
    for name,transformer,features in tx:
        try:
            Var = preprocessor.named_transformers_[name].get_feature_names_out().tolist()
        except AttributeError:
            Var = features
        feature_names = feature_names + Var

    return feature_names
#####fonction pour sauvegarder le modele/gridsearch
def save_model_grid(object_to_save,filename,object_type):
    if object_type=='model':
        ch=filename+'.joblib'
    elif object_type=='gridsearch':
        ch=filename+'.pkl'
    joblib.dump(object_to_save,ch)

#####fonction pour charger le modele/gridsearch
def load_model_grid(ch):
    loaded_object = joblib.load(ch)
    return loaded_model
########fonction pour extraire les données d'un pipeline apres pretraitement
def preprocessed_data(X,pip):
    X_encoded = pip['preprocessor'].fit_transform(X)
    return X_encoded

# %% [markdown]
# ### 1.Load Data From CSV File<a class="anchor" id="ld"></a>

# %%
#df = pd.read_csv('prepared_data.csv', sep='\t')
df = pd.read_csv('df_quantile.csv',sep='\t')

# %%
df.shape
# Out:
# (1541, 17)

# %%
columns=list(df.columns)
columns
# Out:
# ['OSEBuildingID',
#  '%NaturalGas(kBtu)',
#  '%SteamUse(kBtu)',
#  'BuildingType',
#  'NumberofBuildings',
#  'NumberofFloors',
#  'PropertyGFATotal',
#  'ENERGYSTARScore',
#  'SourceEUI(kBtu/sf)',
#  'SiteEnergyUse(kBtu)',
#  'TotalGHGEmissions',
#  'GHGEmissionsIntensity',
#  'tranche_date',
#  'BuildingAge',
#  'groups_neighborhood',
#  'groups_PrimaryPropertyType',
#  'GFABuildingRate']

# %%
target1='TotalGHGEmissions'
target2='SiteEnergyUse(kBtu)'

# %%
f_strong_correlation(0.7 ,df)
# Out:
#                level_0                level_1  corr_coeff
# 0     PropertyGFATotal    SiteEnergyUse(kBtu)    0.716380
# 2  SiteEnergyUse(kBtu)     SourceEUI(kBtu/sf)    0.732017
# 4    TotalGHGEmissions  GHGEmissionsIntensity    0.756458
# 6  SiteEnergyUse(kBtu)      TotalGHGEmissions    0.885268

# %%
#ici on élimine 'OSEBuildingID' et 'SiteEnergyUse(kBtu)'(target2)
cols=list(set(columns)-set(['OSEBuildingID','GHGEmissionsIntensity(kBtu/sf)',target2]))
cols
# Out:
# ['%NaturalGas(kBtu)',
#  'tranche_date',
#  '%SteamUse(kBtu)',
#  'groups_PrimaryPropertyType',
#  'ENERGYSTARScore',
#  'NumberofFloors',
#  'groups_neighborhood',
#  'BuildingType',
#  'TotalGHGEmissions',
#  'GHGEmissionsIntensity',
#  'NumberofBuildings',
#  'GFABuildingRate',
#  'BuildingAge',
#  'PropertyGFATotal',
#  'SourceEUI(kBtu/sf)']

# %%
df=df[cols]

# %%
numercial_cols = [col for col in df.columns if df[col].dtype!="O"]
print(numercial_cols)
# Out:
# ['%NaturalGas(kBtu)', '%SteamUse(kBtu)', 'ENERGYSTARScore', 'NumberofFloors', 'TotalGHGEmissions', 'GHGEmissionsIntensity', 'NumberofBuildings', 'GFABuildingRate', 'BuildingAge', 'PropertyGFATotal', 'SourceEUI(kBtu/sf)']

# %%
categorical_cols = [col for col in df.columns if df[col].dtype=="O"]
print(categorical_cols)
# Out:
# ['tranche_date', 'groups_PrimaryPropertyType', 'groups_neighborhood', 'BuildingType']

# %%
df['BuildingType'].unique()
# Out:
# array(['NonResidential', 'Nonresidential COS', 'SPS-District K-12',
#        'Campus'], dtype=object)

# %%
df['groups_neighborhood'].unique()
# Out:
# array(['Various', 'North', 'Central', 'South'], dtype=object)

# %%
df['tranche_date'].unique()
# Out:
# array(['tranche_date1', 'tranche_date3', 'tranche_date2', 'tranche_date4'],
#       dtype=object)

# %%
df['groups_PrimaryPropertyType'].unique()
# Out:
# array(['Various', 'Commerce', 'Health'], dtype=object)

# %%
df.shape
# Out:
# (1541, 15)

# %%
numercial_cols_for_transformer=list(set(numercial_cols)-set([target1]))

# %%
numercial_cols_for_transformer
# Out:
# ['%NaturalGas(kBtu)',
#  '%SteamUse(kBtu)',
#  'GHGEmissionsIntensity',
#  'NumberofBuildings',
#  'GFABuildingRate',
#  'BuildingAge',
#  'ENERGYSTARScore',
#  'NumberofFloors',
#  'PropertyGFATotal',
#  'SourceEUI(kBtu/sf)']

# %%
font = {
        'weight' : 'bold',
        'size'   : 12}

plt.rc('font', **font)

# %% [markdown]
# ## 2.Build a pipeline <a class="anchor" id="bp"></a>

# %%
# Create pipelines for numerical and categorical features
numeric_transformer = Pipeline(
    steps=[("scaler", StandardScaler())]
)

categorical_transformer = OneHotEncoder(handle_unknown="ignore",drop='first')
 #when using sklearn.compose.ColumnTransformer You need to make sure the output column is not included in the data you create your Preprocessing pipeline with
# Create ColumnTransformer to apply pipeline for each column type
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numercial_cols_for_transformer),
        ("cat", categorical_transformer, categorical_cols),
    ]
)

# %%
feature_after_transformer(preprocessor)
# Out:
# ['%NaturalGas(kBtu)',
#  '%SteamUse(kBtu)',
#  'GHGEmissionsIntensity',
#  'NumberofBuildings',
#  'GFABuildingRate',
#  'BuildingAge',
#  'ENERGYSTARScore',
#  'NumberofFloors',
#  'PropertyGFATotal',
#  'SourceEUI(kBtu/sf)',
#  'tranche_date',
#  'groups_PrimaryPropertyType',
#  'groups_neighborhood',
#  'BuildingType']

# %%
y=df[[target1]]
y= StandardScaler().fit_transform(y)
features=list(set(cols)-set([target1]))
X=df[features]

# %% [markdown]
# #### Continuous target stratification

# %%
bins = np.linspace(0, len(y), 100)

# Save your Y values in a new ndarray,
# broken down by the bins created above.

y_binned = np.digitize(y, bins)

# Pass y_binned to the stratify argument,
# and sklearn will handle the rest

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y_binned,random_state=0)

# %% [markdown]
# ## 3.Idée pour choisir le meilleur modèle <a class="anchor" id="ic"></a>

# %%
regressors = [DummyRegressor(strategy="median",constant=None,quantile=0.5),
              LinearRegression(fit_intercept=True,normalize=True,copy_X=True),
              Ridge(alpha=5,solver='auto',fit_intercept=True),
              Lasso(tol=1e-3,selection='random',fit_intercept=True),
              ElasticNet(tol=1e-3,selection='random',fit_intercept=True),
              RandomForestRegressor(n_estimators=300,max_leaf_nodes=1000,criterion='squared_error'),
              SVR(kernel='rbf',degree=3,gamma='scale'),
              LGBMRegressor(boosting_type='gbdt',num_leaves=31,max_depth=1),
              XGBRegressor(objective ='reg:squarederror',booster="dart",
                  n_estimators = 100)
              ]

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_regression

for model in regressors:
    start = time()
    #select=SelectKBest(score_func=f_regression,k=8)
    #pip = Pipeline(steps=[("preprocessor", preprocessor),("selector",select),("model", model)])
    pip = Pipeline(steps=[("preprocessor", preprocessor),("model", model)])
    
    pip.fit(X_train, y_train)
    train_time = time() - start
    start = time()
    y_pred = pip.predict(X_test)
    predict_time = time()-start    
    print(model)
    print("\tTraining time: %0.3fs" % train_time)
    print("\tPrediction time: %0.3fs" % predict_time)
   
    print("\tMean squared error:", mean_squared_error(y_test, y_pred))
    print("\tRMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
    print("\tR2 score:", r2_score(y_test, y_pred))
    print()
# Out:
# DummyRegressor(quantile=0.5, strategy='median')
# 	Training time: 0.031s
# 	Prediction time: 0.000s
# 	Mean squared error: 1.0524340965152799
# 	RMSE: 1.0258821065382122
# 	R2 score: -0.0016416340593232714
#
# LinearRegression(normalize=True)
# 	Training time: 0.016s
# 	Prediction time: 0.016s
# 	Mean squared error: 0.04390833625286538
# 	RMSE: 0.2095431608353405
# 	R2 score: 0.958210763202399
#
# Ridge(alpha=5)
# 	Training time: 0.016s
# 	Prediction time: 0.016s
# 	Mean squared error: 0.044090201936676274
# 	RMSE: 0.2099766699818727
# 	R2 score: 0.9580376747008816
#
# Lasso(selection='random', tol=0.001)
# 	Training time: 0.016s
# 	Prediction time: 0.000s
# 	Mean squared error: 1.0533994455165316
# 	RMSE: 1.0263524957423409
# 	R2 score: -0.0025603934897266978
#
# ElasticNet(selection='random', tol=0.001)
# 	Training time: 0.016s
# 	Prediction time: 0.016s
# 	Mean squared error: 0.7490360605551983
# 	RMSE: 0.865468694150862
# 	R2 score: 0.28711383815093416
#
# RandomForestRegressor(max_leaf_nodes=1000, n_estimators=300)
# 	Training time: 3.053s
# 	Prediction time: 0.062s
# 	Mean squared error: 0.024235457235495875
# 	RMSE: 0.15567741401852703
# 	R2 score: 0.9769341918245381
#
# SVR()
# 	Training time: 0.109s
# 	Prediction time: 0.016s
# 	Mean squared error: 0.039935984862173576
# 	RMSE: 0.19983989807386707
# 	R2 score: 0.9619914013926713
#
# LGBMRegressor(max_depth=1)
# 	Training time: 0.078s
# 	Prediction time: 0.000s
# 	Mean squared error: 0.054317108603543
# 	RMSE: 0.23306031108608563
# 	R2 score: 0.948304337916098
#
# XGBRegressor(base_score=0.5, booster='dart', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)
# 	Training time: 1.357s
# 	Prediction time: 0.047s
# 	Mean squared error: 0.024856686679318087
# 	RMSE: 0.15766003513673998
# 	R2 score: 0.9763429440900756

# %% [markdown]
# **Note**
# <br>
# Dans la suite on va travailler sur les 3 modèles retenus ayant les 4 premiers meilleurs coefficiet de détermination r2 notamment LinearRegression,Ridge,SVR et LGBMRegressor.

# %% [markdown]
# ## 4.Modèles de machine learning choisis<a class="anchor" id="mml"></a>

# %% [markdown]
# ### 4.1.Regression linéaire

# %%
#LinearRegression fits a linear model with coefficients w = (w1, …, wp) to minimize the residual sum of squares between the observed targets in the dataset, 
#and the targets predicted by the linear approximation.

# %%
clf_lr = Pipeline(
    steps=[("preprocessor", preprocessor), ("model", LinearRegression(fit_intercept=True,normalize=False,copy_X=True))]
)
clf_lr.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['%NaturalGas(kBtu)',
#                                                    '%SteamUse(kBtu)',
#                                                    'GHGEmissionsIntensity',
#                                                    'NumberofBuildings',
#                                                    'GFABuildingRate',
#                                                    'BuildingAge',
#                                                    'ENERGYSTARScore',
#                                                    'NumberofFloors',
#                                                    'PropertyGFATotal',
#                                                    'SourceEUI(kBtu/sf)']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['tranche_date',
#                                                    'groups_PrimaryPropertyType',
#                                                    'groups_neighborhood',
#                                                    'BuildingType'])])),
#                 ('model', LinearRegression(normalize=False))])

# %%
save_model_grid(clf_lr,'regr_pred1','model')

# %% [markdown]
# ### 4.1.1.Indicateurs de performance

# %%
f_performance(clf_lr)
# Out:
# ******************
# MSE : 0.044
# RMSE : 0.210
# R2 : 0.958

# %% [markdown]
# ### 4.1.2.Coéfficients du modèle

# %%
clf_lr.named_steps['model'].intercept_
# Out:
# array([0.09422971])

# %%
f_coeff(clf_lr)
# Out:
#                                Columns  Estimated Coefficient
# 0                    %NaturalGas(kBtu)                0.068185
# 1                      %SteamUse(kBtu)                0.058775
# 2                GHGEmissionsIntensity                0.701805
# 3                    NumberofBuildings                0.001127
# 4                      GFABuildingRate               -0.009662
# 5                          BuildingAge               -0.061061
# 6                      ENERGYSTARScore                0.014145
# 7                       NumberofFloors                0.009112
# 8                     PropertyGFATotal                0.579239
# 9                   SourceEUI(kBtu/sf)                0.039784
# 10          tranche_date_tranche_date2               -0.041792
# 11          tranche_date_tranche_date3               -0.069205
# 12          tranche_date_tranche_date4               -0.087453
# 13   groups_PrimaryPropertyType_Health                0.037882
# 14  groups_PrimaryPropertyType_Various                0.056899
# 15           groups_neighborhood_North                0.031156
# 16           groups_neighborhood_South               -0.014897
# 17         groups_neighborhood_Various                0.034085
# 18         BuildingType_NonResidential               -0.122569
# 19     BuildingType_Nonresidential COS               -0.008553
# 20      BuildingType_SPS-District K-12               -0.118017

# %%
def f_plot_coeff(pip_reg):
    # plotting the coefficient score
    

    fig, ax = plt.subplots(figsize =(25, 10))
 
    color =['tab:gray', 'tab:blue', 'tab:orange',
            'tab:green', 'tab:red', 'tab:purple', 'tab:brown',
            'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan',
            'tab:orange', 'tab:green', 'tab:blue', 'tab:olive']
    
    df_coefficient=f_coeff(pip_reg)
    ax.bar(df_coefficient["Columns"],
    df_coefficient['Estimated Coefficient '],
       color=color
           )

    ax.spines['bottom'].set_position('zero')
 
    plt.style.use('ggplot')
    plt.xticks(rotation=30, ha='right')
    plt.show()

# %%
f_plot_coeff(clf_lr)

# %% [markdown]
# **Observations**
# <br>
# On peut remarquer que les features les plus importants sont: 'GHGEmissionsIntensity' et 'PropertyGFATotal'

# %% [markdown]
# ### 4.1.3.Feature importance (shap values)

# %%
X_train_encoded=preprocessed_data(X_train,clf_lr)

# %%
shap.initjs()
ex = shap.LinearExplainer(clf_lr['model'], X_train_encoded)
shap_values = ex.shap_values(X_train_encoded)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
#Observation 1
shap.force_plot(ex.expected_value, shap_values[0,:], X_train_encoded[0,:],feature_names=feature_after_transformer(preprocessor))
# Out:
# <div id='i2OAMSBI32I6ZLIFHEMDP'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.1738552248574428, "outValue": 0.7061315767376144, "link": "identity", "featureNames": ["%NaturalGas(kBtu)", "%SteamUse(kBtu)", "GHGEmissionsIntensity", "NumberofBuildings", "GFABuildingRate", "BuildingAge", "ENERGYSTARScore", "NumberofFloors", "PropertyGFATotal", "SourceEUI(kBtu/sf)", "tranche_date_tranche_date2", "tranche_date_tranche_date3", "tranche_date_tranche_date4", "groups_PrimaryPropertyType_Health", "groups_PrimaryPropertyType_Various", "groups_neighborhood_North", "groups_neighborhood_South", "groups_neighborhood_Various", "BuildingType_NonResidential", "BuildingType_Nonresidential COS", "BuildingType_SPS-District K-12"], "features": {"0": {"effect": -0.11186287798067437, "value": -1.5680442415858884}, "1": {"effect": 0.2040205471931064, "value": 3.510848374678129}, "2": {"effect": -0.13372198332001137, "value": -0.006158670952018135}, "3": {"effect": -0.0002573470582435899, "value": -0.17786881912671637}, "4": {"effect": -0.004433496716018465, "value": 0.5201979682926341}, "5": {"effect": -0.09503493506514107, "value": 1.6483960709263894}, "6": {"effect": 0.013750381317458484, "value": 0.8379917471476047}, "7": {"effect": 0.009056553484965152, "value": 0.9324974356166852}, "8": {"effect": 0.6152638983664374, "value": 1.105191058325411}, "9": {"effect": -0.008237786927479906, "value": -0.15752131631236915}, "10": {"effect": 0.010448015962746105, "value": 0.0}, "11": {"effect": 0.012456917526028434, "value": 0.0}, "12": {"effect": 0.013992459722866125, "value": 0.0}, "13": {"effect": -0.0030305963160802214, "value": 0.0}, "14": {"effect": 0.016500683597734944, "value": 1.0}, "15": {"effect": -0.0037387565566569594, "value": 0.0}, "16": {"effect": 0.0005958869143105931, "value": 0.0}, "17": {"effect": 0.007157805704293748, "value": 1.0}, "18": {"effect": -0.012256858619324653, "value": 1.0}, "19": {"effect": 0.0004276711927934586, "value": 0.0}, "20": {"effect": 0.0011801694570615154, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i2OAMSBI32I6ZLIFHEMDP')
#   );
# </script>

# %%
#Observation 2
shap.force_plot(ex.expected_value, shap_values[1,:], X_train_encoded[1,:],feature_names=feature_after_transformer(preprocessor))
# Out:
# <div id='i62B3KUJHPJ25MJD95XR2'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.1738552248574428, "outValue": -2.000640068280688, "link": "identity", "featureNames": ["%NaturalGas(kBtu)", "%SteamUse(kBtu)", "GHGEmissionsIntensity", "NumberofBuildings", "GFABuildingRate", "BuildingAge", "ENERGYSTARScore", "NumberofFloors", "PropertyGFATotal", "SourceEUI(kBtu/sf)", "tranche_date_tranche_date2", "tranche_date_tranche_date3", "tranche_date_tranche_date4", "groups_PrimaryPropertyType_Health", "groups_PrimaryPropertyType_Various", "groups_neighborhood_North", "groups_neighborhood_South", "groups_neighborhood_Various", "BuildingType_NonResidential", "BuildingType_Nonresidential COS", "BuildingType_SPS-District K-12"], "features": {"0": {"effect": 0.03221517408805906, "value": 0.5450156576727365}, "1": {"effect": -0.018289575024219108, "value": -0.2715220223344368}, "2": {"effect": -1.2477787395696671, "value": -1.5935753944093023}, "3": {"effect": -0.0002573470582435899, "value": -0.17786881912671637}, "4": {"effect": -0.004433496716018465, "value": 0.5201979682926341}, "5": {"effect": 0.0342894322474537, "value": -0.4695669379635363}, "6": {"effect": 0.058367145081708774, "value": 3.9922780323468503}, "7": {"effect": -0.013651273042060857, "value": -1.5594768647708341}, "8": {"effect": -0.8613031457996938, "value": -1.4439604362286995}, "9": {"effect": -0.09576740869327417, "value": -2.3576616853030625}, "10": {"effect": -0.031344047888238316, "value": 1.0}, "11": {"effect": 0.012456917526028434, "value": 0.0}, "12": {"effect": 0.013992459722866125, "value": 0.0}, "13": {"effect": -0.0030305963160802214, "value": 0.0}, "14": {"effect": -0.04039822535997175, "value": 0.0}, "15": {"effect": 0.027417548082151036, "value": 1.0}, "16": {"effect": 0.0005958869143105931, "value": 0.0}, "17": {"effect": -0.026926983363771726, "value": 0.0}, "18": {"effect": -0.012256858619324653, "value": 1.0}, "19": {"effect": 0.0004276711927934586, "value": 0.0}, "20": {"effect": 0.0011801694570615154, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i62B3KUJHPJ25MJD95XR2')
#   );
# </script>

# %%
#toutes les observations
shap.force_plot(ex.expected_value, shap_values, X_train_encoded,feature_names=feature_after_transformer(preprocessor))
# Out:
# <div id='i9RWRFYPZVULCFFQR8OIY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.1738552248574428, "link": "identity", "featureNames": ["%NaturalGas(kBtu)", "%SteamUse(kBtu)", "GHGEmissionsIntensity", "NumberofBuildings", "GFABuildingRate", "BuildingAge", "ENERGYSTARScore", "NumberofFloors", "PropertyGFATotal", "SourceEUI(kBtu/sf)", "tranche_date_tranche_date2", "tranche_date_tranche_date3", "tranche_date_tranche_date4", "groups_PrimaryPropertyType_Health", "groups_PrimaryPropertyType_Various", "groups_neighborhood_North", "groups_neighborhood_South", "groups_neighborhood_Various", "BuildingType_NonResidential", "BuildingType_Nonresidential COS", "BuildingType_SPS-District K-12"], "explanations": [{"outValue": 0.7061315767376144, "simIndex": 1062.0, "features": {"0": {"effect": -0.11186287798067437, "value": -1.5680442415858884}, "1": {"effect": 0.2040205471931064, "value": 3.510848374678129}, "2": {"effect": -0.13372198332001137, "value": -0.006158670952018135}, "3": {"effect": -0.0002573470582435899, "value": -0.17786881912671637}, "4": {"effect": -0.004433496716018465, "value": 0.5201979682926341}, "5": {"effect": -0.09503493506514107, "value": 1.6483960709263894}, "6": {"effect": 0.013750381317458484, "value": 0.8379917471476047}, "7": {"effect": 0.009056553484965152, "value": 0.9324974356166852}, "8": {"effect": 0.6152638983664374, "value": 1.105191058325411}, "9": {"effect": -0.008237786927479906, "value": -0.15752131631236915}, "10": {"effect": 0.010448015962746105, "value": 0.0}, "11": {"effect": 0.012456917526028434, "value": 0.0}, "12": {"effect": 0.013992459722866125, "value": 0.0}, "13": {"effect": -0.0030305963160802214, "value": 0.0}, "14": {"effect": 0.016500683597734944, "value": 1.0}, "15": {"effect": -0.0037387565566569594, "value": 0.0}, "16": {"effect": 0.0005958869143105931, "value": 0.0}, "17": {"effect": 0.007157805704293748, "value": 1.0}, "18": {"effect": -0.012256858619324653, "value": 1.0}, "19": {"effect": 0.0004276711927934586, "value": 0.0}, "20": {"effect": 0.0011801694570615154, "value": 0.0}}}, {"outValue": -2.000640068280688, "simIndex": 359.0, "features": {"0": {"effect": 0.03221517408805906, "value": 0.5450156576727365}, "1": {"effect": -0.018289575024219108, "value": -0.2715220223344368}, "2": {"effect": -1.2477787395696671, "value": -1.5935753944093023}, "3": {"effect": -0.0002573470582435899, "value": -0.17786881912671637}, "4": {"effect": -0.004433496716018465, "value": 0.5201979682926341}, "5": {"effect": 0.0342894322474537, "value": -0.4695669379635363}, "6": {"effect": 0.058367145081708774, "value": 3.9922780323468503}, "7": {"effect": -0.013651273042060857, "value": -1.5594768647708341}, "8": {"effect": -0.8613031457996938, "value": -1.4439604362286995}, "9": {"effect": -0.09576740869327417, "value": -2.3576616853030625}, "10": {"effect": -0.031344047888238316, "value": 1.0}, "11": {"effect": 0.012456917526028434, "value": 0.0}, "12": {"effect": 0.013992459722866125, "value": 0.0}, "13": {"effect": -0.0030305963160802214, "value": 0.0}, "14": {"effect": -0.04039822535997175, "value": 0.0}, "15": {"effect": 0.027417548082151036, "value": 1.0}, "16": {"effect": 0.0005958869143105931, "value": 0.0}, "17": {"effect": -0.026926983363771726, "value": 0.0}, "18": {"effect": -0.012256858619324653, "value": 1.0}, "19": {"effect": 0.0004276711927934586, "value": 0.0}, "20": {"effect": 0.0011801694570615154, "value": 0.0}}}, {"outValue": 0.4340947017969286, "simIndex": 783.0, "features": {"0": {"effect": 0.0474450538263889, "value": 0.7683782565107868}, "1": {"effect": -0.018289575024219108, "value": -0.2715220223344368}, "2": {"effect": 0.23700069835068138, "value": 0.5220831635395006}, "3": {"effect": -0.0002573470582435899, "value": -0.17786881912671637}, "4": {"effect": -0.004433496716018465, "value": 0.5201979682926341}, "5": {"effect": 0.03798441417067069, "value": -0.5300801667889627}, "6": {"effect": -0.011575564114546143, "value": -0.9524850959955031}, "7": {"effec ...

# %% [markdown]
# **Observations**
# <b>
# Les valeurs en bleu(GHGEmission et PropertyGFAtotal) peuvent être considérées comme des valeurs ayant une influence positive sur la prédiction, tandis que les valeurs en rouge ont une influence négative sur la prédiction.

# %%
shap.summary_plot(shap_values, X_train_encoded,feature_names=feature_after_transformer(preprocessor))

# %% [markdown]
# **Observations**
# <br>
# La visualization de 'variables’ importance' coincide avec les  coefficients du modèle de la regression linéaire.

# %% [markdown]
# #### Cross validation

# %%
scores = cross_val_score(clf_lr, X, y, cv=10,scoring='r2')#coefficient of determination (pr défaut). how well the regression model fits the observed data.a higher coefficient indicates a better fit for the model.
scores
# Out:
# array([0.85083974, 0.92538723, 0.96296171, 0.94682282, 0.91195931,
#        0.94634104, 0.94425963, 0.93872602, 0.95369036, 0.90500864])

# %%
print(" mean of R2= %0.2f" % scores.mean())
# Out:
#  mean of R2= 0.93

# %% [markdown]
# #### Ajustement des paramètres en utilisant gridsearch

# %%
#Paramètres à ajuster
LinearRegression().get_params().keys()
# Out:
# dict_keys(['copy_X', 'fit_intercept', 'n_jobs', 'normalize', 'positive'])

# %%
#LinearRegression().get_params().keys()
param_grid = {
    
    "model__fit_intercept": [True, False],
    "model__copy_X": [True, False],
    "model__positive": [True, False],
    "model__normalize": [True, False],
    #"model": [LinearRegression()]
}

grid_search = GridSearchCV(clf_lr, param_grid, cv=10)
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['NumberofBuildings',
#                                                                           '%NaturalGas(kBtu)',
#                                                                           'NumberofFloors',
#                                                                           '%SteamUse(kBtu)',
#                                                                           'ENERGYSTARScore',
#                                                                           'SourceEUI(kBtu/sf)',
#                                                                           'GFABuildingRate',
#                                                                           'PropertyGFATotal',
#                                                                           'GHGEmissionsIntensity',
#                                                                           'BuildingAge']),
#                                                                         ('cat',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        handle_unknown='ignore'),
#                                                                          ['groups_PrimaryPropertyType',
#                                                                           'BuildingType',
#                                                                           'groups_neighborhood',
#                                                                           'tranche_date'])])),
#                                        ('model',
#                                         LinearRegression(normalize=True))]),
#              param_grid={'model__copy_X': [True, False],
#                          'model__fit_intercept': [True, False],
#                          'model__normalize': [True, False],
#                          'model__positive': [True, False]})

# %%
save_model_grid(grid_search,'grid_search_LR','gridsearch')

# %%
# cv results
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.035322  4.402594e-02         0.007805        0.007805
# 1        0.015624  1.140678e-06         0.009372        0.007653
# 2        0.015624  7.838861e-07         0.007812        0.007812
# 3        0.017065  4.187696e-03         0.006327        0.006830
# 4        0.015708  1.670760e-04         0.008613        0.007368
# 5        0.015625  1.052558e-06         0.007812        0.007812
# 6        0.014061  4.687119e-03         0.006250        0.007654
# 7        0.015624  9.302878e-06         0.003125        0.006250
# 8        0.017262  4.658308e-03         0.007085        0.007414
# 9        0.016489  2.599399e-03         0.008721        0.004183
# 10       0.016462  2.138808e-03         0.007885        0.006052
# 11       0.014984  2.548404e-03         0.008690        0.005457
# 12       0.014237  4.761034e-03         0.008725        0.004186
# 13       0.015737  1.736494e-04         0.006665        0.006049
# 14       0.014943  2.554845e-03         0.007886        0.006053
# 15       0.017436  3.287268e-03         0.006403        0.003201
#
#    param_model__copy_X param_model__fit_intercept param_model__normalize  \
# 0                 True                       True                   True
# 1                 True                       True                   True
# 2                 True                       True                  False
# 3                 True                       True                  False
# 4                 True                      False                   True
# 5                 True                      False                   True
# 6                 True                      False                  False
# 7                 True                      False                  False
# 8                False                       True                   True
# 9                False                       True                   True
# 10               False                       True                  False
# 11               False                       True                  False
# 12               False                      False                   True
# 13               False                      False                   True
# 14               False                      False                  False
# 15               False                      False                  False
#
#    param_model__positive                                             params  \
# 0                   True  {'model__copy_X': True, 'model__fit_intercept'...
# 1                  False  {'model__copy_X': True, 'model__fit_intercept'...
# 2                   True  {'model__copy_X': True, 'model__fit_intercept'...
# 3                  False  {'model__copy_X': True, 'model__fit_intercept'...
# 4                   True  {'model__copy_X': True, 'model__fit_intercept'...
# 5                  False  {'model__copy_X': True, 'model__fit_intercept'...
# 6                   True  {'model__copy_X': True, 'model__fit_intercept'...
# 7                  False  {'model__copy_X': True, 'model__fit_intercept'...
# 8                   True  {'model__copy_X': False, 'model__fit_intercept...
# 9                  False  {'model__copy_X': False, 'model__fit_intercept...
# 10                  True  {'model__copy_X': False, 'model__fit_intercept...
# 11                 False  {'model__copy_X': False, 'model__fit_intercept...
# 12                  True  {'model__copy_X': False, 'model__fit_intercept...
# 13                 False  {'model__copy_X': False, 'model__fit_intercept...
# 14                  True  {'model__copy_X': False, 'model__fit_intercept...
# 15                 False  {'model__copy_X': False, 'model__fit_intercept...
#
#     split0_test_score  ...  split3_test_score  split4_test_score  \
# 0            0.923572  ...           0.905984           0.949858
# 1            0.924682  ...           0.905119           0.951636
# 2            0.923572  ...           0.905984           0.949858
# 3            0.924682  ...           0.905119           0.951636
# 4            0.921569  ...           0.904395           0.950611
# 5            0.924945  ...           0.905344           0.951380
# 6            0.921569  ...           0.904395           0.950611
# 7            0.924945  ...           0.905344           0.951380
# 8            0.923572  ...           0.905984           0.949858
# 9            0.924682  ...           0.905119           0.951636
# 10           0.923572  ...           0.905984           0.949858
# 11           0.924682  ...           0.905119           0.951636
# 12           0.921569  ...           0.904395           0.950611
# 13           0.924945  ...           0.905344           0.951380
# 14           0.921569  ...           0.904395           0.950611
# 15           0.924945  ...           0.905344           0.951380
#
#     split5_test_score  split6_test_score  split7_test_score  \
# 0            0.913594           0.956702           0.953885
# 1            0.913628           0.957959           0.951301
# 2            0.913594           0.956702           0.953885
# 3            0.913628           0.957959           0.951301
# 4            0.912100           0.957197           0.952597
# 5            0.913496           0.957606           0.952081
# 6            0.912100           0.957197           0.952597
# 7            0.913496           0.957606           0.952081
# 8            0.913594           0.956702           0.953885
# 9            0.913628           0.957959           0.951301
# 10           0.913594           0.956702           0.953885
# 11           0.913628           0.957959           0.951301
# 12           0.912100           0.957197           0.952597
# 13           0.913496           0.957606           0.952081
# 14           0.912100           0.957197           0.952597
# 15           0.913496           0.957606           0.952081
#
#     split8_test_score  split9_test_score  mean_test_score  std_test_score  \
# 0            0.956077           0.959137         0.942482        0.019167
# 1            0.956196           0.958967         0.942599        0.019281
# 2            0.956077           0.959137         0.942482        0.019167
# 3            0.956196           0.958967         0.942599        0.019281
# 4            0.955250           0.959440         0.942112        0.019838
# 5            0.956103           0.959193         0.942639        0.019229
# 6            0.955250           0.959440         0.942112        0.019838
# 7            0.956103           0.959193         0.942639        0.019229
# 8            0.956077           0.959137         0.942482        0.019167
# 9            0.956196           0.958967         0.942599        0.019281
# 10           0.956077           0.959137         0.942482        0.019167
# 11           0.956196           0.958967         0.942599        0.019281
# 12           0.955250           0.959440         0.942112        0.019838
# 13           0.956103           0.959193         0.942639        0.019229
# 14           0.955250           0.959440         0.942112        0.019838
# 15           0.956103           0.959193         0.942639        0.019229
#
#     rank_test_score
# 0                 9
# 1                 5
# 2                 9
# 3                 5
# 4                13
# 5                 1
# 6                13
# 7                 1
# 8                 9
# 9                 5
# 10                9
# 11                5
# 12               13
# 13                1
# 14               13
# 15                1
#
# [16 rows x 22 columns]

# %%
grid_search.best_params_
# Out:
# {'model__copy_X': True,
#  'model__fit_intercept': False,
#  'model__normalize': True,
#  'model__positive': False}

# %%
best_estim=grid_search.best_estimator_
f_performance(best_estim)
# Out:
# ******************
# MSE : 0.044
# RMSE : 0.210
# R2 : 0.958

# %%
save_model_grid(best_estim,'best_LR','model')

# %% [markdown]
# **Observations**
# <br>
#
# pas bcp de paramètre avec la regression linéaire regardons la regression polynomial

# %%
numeric_transformer_pol = Pipeline(
    steps=[("scaler", StandardScaler()),('poly', PolynomialFeatures(degree=5))]
)

#categorical_transformer = OneHotEncoder(handle_unknown="ignore")
 #when using sklearn.compose.ColumnTransformer You need to make sure the output column is not included in the data you create your Preprocessing pipeline with
# Create ColumnTransformer to apply pipeline for each column type
preprocessor_pol = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer_pol, numercial_cols_for_transformer),
        ("cat", categorical_transformer, categorical_cols),
    ]
)

# %%
clf_pr = Pipeline(
    steps=[("preprocessor", preprocessor), ("model", LinearRegression())])
clf_pr.fit(X_train,y_train)
f_performance(clf_pr)
# Out:
# ******************
# MSE : 0.044
# RMSE : 0.210
# R2 : 0.958

# %% [markdown]
# ### 4.2.Ridge regression

# %%
clf_rr = Pipeline(
    steps=[("preprocessor", preprocessor), ("model", Ridge(alpha=2,solver='auto',fit_intercept=True))]
)
clf_rr.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['%NaturalGas(kBtu)',
#                                                    '%SteamUse(kBtu)',
#                                                    'GHGEmissionsIntensity',
#                                                    'NumberofBuildings',
#                                                    'GFABuildingRate',
#                                                    'BuildingAge',
#                                                    'ENERGYSTARScore',
#                                                    'NumberofFloors',
#                                                    'PropertyGFATotal',
#                                                    'SourceEUI(kBtu/sf)']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['tranche_date',
#                                                    'groups_PrimaryPropertyType',
#                                                    'groups_neighborhood',
#                                                    'BuildingType'])])),
#                 ('model', Ridge(alpha=2))])

# %% [markdown]
# ### 4.2.1.Indicateurs de performance

# %%
f_performance(clf_rr)
# Out:
# ******************
# MSE : 0.044
# RMSE : 0.210
# R2 : 0.958

# %% [markdown]
#  ### 4.2.2.Coéfficients du modèle

# %%
clf_rr.named_steps['model'].intercept_
# Out:
# array([0.06399501])

# %%
f_coeff(clf_rr)
# Out:
#                                Columns  Estimated Coefficient
# 0                    NumberofBuildings                0.002717
# 1                    %NaturalGas(kBtu)                0.071559
# 2                       NumberofFloors                0.009361
# 3                      %SteamUse(kBtu)                0.060459
# 4                      ENERGYSTARScore                0.013881
# 5                   SourceEUI(kBtu/sf)                0.043375
# 6                      GFABuildingRate               -0.009494
# 7                     PropertyGFATotal                0.577034
# 8                GHGEmissionsIntensity                0.696328
# 9                          BuildingAge               -0.053853
# 10   groups_PrimaryPropertyType_Health                0.036183
# 11  groups_PrimaryPropertyType_Various                0.056115
# 12         BuildingType_NonResidential               -0.099153
# 13     BuildingType_Nonresidential COS                0.013909
# 14      BuildingType_SPS-District K-12               -0.074014
# 15           groups_neighborhood_North                0.028472
# 16           groups_neighborhood_South               -0.016116
# 17         groups_neighborhood_Various                0.031815
# 18          tranche_date_tranche_date2               -0.031166
# 19          tranche_date_tranche_date3               -0.052456
# 20          tranche_date_tranche_date4               -0.067132

# %%
f_plot_coeff(clf_rr)

# %%
shap.initjs()
ex = shap.LinearExplainer(clf_rr['model'], X_train_encoded)
shap_values = ex.shap_values(X_train_encoded)

shap.summary_plot(shap_values, X_train_encoded,feature_names=feature_after_transformer(preprocessor))
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
shap.summary_plot(shap_values, X_train_encoded, plot_type='bar',feature_names=feature_after_transformer(preprocessor))

# %% [markdown]
# **Observations**
# <br>
# Pareil pour la regression linéaire,
# on peut remarquer que les features les plus importants sont: 'GHGEmissionsIntensity','BuildingType_Campus' et 'PropertyGFATotal

# %% [markdown]
# ### 4.2.3.Optimisation du modèle

# %% [markdown]
# #### Cross validation

# %%
scores = cross_val_score(clf_rr, X, y, cv=10,scoring='r2')#coefficient of determination (pr défaut). how well the regression model fits the observed data.a higher coefficient indicates a better fit for the model.
scores
# Out:
# array([0.85018738, 0.9248963 , 0.96280377, 0.94689395, 0.91282883,
#        0.94643643, 0.9445412 , 0.93899553, 0.95355461, 0.90618323])

# %%
print(" mean of  R2= %0.2f" % scores.mean())
# Out:
#  mean of  R2= 0.93

# %% [markdown]
# #### Ajustement des paramètres

# %%
Ridge().get_params().keys()
# Out:
# dict_keys(['alpha', 'copy_X', 'fit_intercept', 'max_iter', 'normalize', 'positive', 'random_state', 'solver', 'tol'])

# %%
#{'alpha': [1,0.1,0.01,0.001,0.0001,0] , "fit_intercept": [True, False], "solver": ['svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']}

# %%
param_grid = {
    
    "model__alpha": [1,0.1,0.01,0.001,0.0001,0,5,10],
    "model__solver": ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs'],
    "model__fit_intercept": [True, False],
    "model__normalize": [True, False],
    #"model": [LinearRegression()]
}

grid_search = GridSearchCV(clf_rr, param_grid, cv=10)
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['NumberofBuildings',
#                                                                           '%NaturalGas(kBtu)',
#                                                                           'NumberofFloors',
#                                                                           '%SteamUse(kBtu)',
#                                                                           'ENERGYSTARScore',
#                                                                           'SourceEUI(kBtu/sf)',
#                                                                           'GFABuildingRate',
#                                                                           'PropertyGFATotal',
#                                                                           'GHGEmissionsIntensity',
#                                                                           'BuildingAge']),
#                                                                         ('cat',
#                                                                          OneHo...
#                                                                                        handle_unknown='ignore'),
#                                                                          ['groups_PrimaryPropertyType',
#                                                                           'BuildingType',
#                                                                           'groups_neighborhood',
#                                                                           'tranche_date'])])),
#                                        ('model', Ridge(alpha=2))]),
#              param_grid={'model__alpha': [1, 0.1, 0.01, 0.001, 0.0001, 0, 5,
#                                           10],
#                          'model__fit_intercept': [True, False],
#                          'model__normalize': [True, False],
#                          'model__solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                            'sparse_cg', 'sag', 'saga',
#                                            'lbfgs']})

# %%
save_model_grid(grid_search_clf_rr,'gridsearch_RR','gridsearch')

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.017413      0.003300         0.008693        0.006529
# 1         0.035948      0.055956         0.009367        0.007648
# 2         0.016901      0.006977         0.007914        0.006087
# 3         0.021014      0.005519         0.005557        0.005044
# 4         0.022750      0.012560         0.010942        0.010013
# ..             ...           ...              ...             ...
# 251       0.026053      0.002325         0.009701        0.001485
# 252       0.023923      0.001190         0.008501        0.001566
# 253       0.036922      0.007889         0.012995        0.004641
# 254       0.039772      0.006892         0.011294        0.002411
# 255       0.015993      0.003461         0.000000        0.000000
#
#     param_model__alpha param_model__fit_intercept param_model__normalize  \
# 0                    1                       True                   True
# 1                    1                       True                   True
# 2                    1                       True                   True
# 3                    1                       True                   True
# 4                    1                       True                   True
# ..                 ...                        ...                    ...
# 251                 10                      False                  False
# 252                 10                      False                  False
# 253                 10                      False                  False
# 254                 10                      False                  False
# 255                 10                      False                  False
#
#     param_model__solver                                             params  \
# 0                  auto  {'model__alpha': 1, 'model__fit_intercept': Tr...
# 1                   svd  {'model__alpha': 1, 'model__fit_intercept': Tr...
# 2              cholesky  {'model__alpha': 1, 'model__fit_intercept': Tr...
# 3                  lsqr  {'model__alpha': 1, 'model__fit_intercept': Tr...
# 4             sparse_cg  {'model__alpha': 1, 'model__fit_intercept': Tr...
# ..                  ...                                                ...
# 251                lsqr  {'model__alpha': 10, 'model__fit_intercept': F...
# 252           sparse_cg  {'model__alpha': 10, 'model__fit_intercept': F...
# 253                 sag  {'model__alpha': 10, 'model__fit_intercept': F...
# 254                saga  {'model__alpha': 10, 'model__fit_intercept': F...
# 255               lbfgs  {'model__alpha': 10, 'model__fit_intercept': F...
#
#      split0_test_score  ...  split3_test_score  split4_test_score  \
# 0             0.783886  ...           0.764074           0.801938
# 1             0.783886  ...           0.764074           0.801938
# 2             0.783886  ...           0.764074           0.801938
# 3             0.783923  ...           0.764085           0.801866
# 4             0.783891  ...           0.764052           0.801928
# ..                 ...  ...                ...                ...
# 251           0.925406  ...           0.906850           0.950812
# 252           0.925309  ...           0.906850           0.950826
# 253           0.925499  ...           0.906730           0.950864
# 254           0.925535  ...           0.906805           0.950861
# 255                NaN  ...                NaN                NaN
#
#      split5_test_score  split6_test_score  split7_test_score  \
# 0             0.827136           0.822552           0.795186
# 1             0.827136           0.822552           0.795186
# 2             0.827136           0.822552           0.795186
# 3             0.827094           0.822621           0.795203
# 4             0.827153           0.822540           0.795198
# ..                 ...                ...                ...
# 251           0.919491           0.958607           0.951889
# 252           0.919412           0.958813           0.951893
# 253           0.919153           0.958643           0.951886
# 254           0.919318           0.958632           0.951907
# 255                NaN                NaN                NaN
#
#      split8_test_score  split9_test_score  mean_test_score  std_test_score  \
# 0             0.755123           0.779737         0.783136        0.027297
# 1             0.755123           0.779737         0.783136        0.027297
# 2             0.755123           0.779737         0.783136        0.027297
# 3             0.755147           0.779762         0.783130        0.027305
# 4             0.755116           0.779694         0.783134        0.027297
# ..                 ...                ...              ...             ...
# 251           0.954508           0.957691         0.942757        0.017671
# 252           0.954471           0.957757         0.942765        0.017714
# 253           0.954594           0.957718         0.942730        0.017744
# 254           0.954528           0.957723         0.942758        0.017704
# 255                NaN                NaN              NaN             NaN
#
#      rank_test_score
# 0                205
# 1                205
# 2                205
# 3                209
# 4                208
# ..               ...
# 251               22
# 252               19
# 253               46
# 254               21
# 255              256
#
# [256 rows x 22 columns]

# %%
grid_search.best_params_
# Out:
# {'model__alpha': 5,
#  'model__fit_intercept': False,
#  'model__normalize': True,
#  'model__solver': 'sparse_cg'}

# %%
best_estim=grid_search.best_estimator_
f_performance(best_estim)
# Out:
# ******************
# MSE : 0.044
# RMSE : 0.210
# R2 : 0.958

# %%
save_model_grid(best_estim,'best_RR','model')

# %% [markdown]
# #####

# %% [markdown]
# ### 4.3.SVR

# %%
clf_svr = Pipeline(
    steps=[("preprocessor", preprocessor), ("model", SVR(kernel='rbf',degree=3,gamma='scale'))]
)
clf_svr.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['%NaturalGas(kBtu)',
#                                                    '%SteamUse(kBtu)',
#                                                    'GHGEmissionsIntensity',
#                                                    'NumberofBuildings',
#                                                    'GFABuildingRate',
#                                                    'BuildingAge',
#                                                    'ENERGYSTARScore',
#                                                    'NumberofFloors',
#                                                    'PropertyGFATotal',
#                                                    'SourceEUI(kBtu/sf)']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['tranche_date',
#                                                    'groups_PrimaryPropertyType',
#                                                    'groups_neighborhood',
#                                                    'BuildingType'])])),
#                 ('model', SVR())])

# %% [markdown]
# ### 4.3.1.Indicateurs de performance

# %%
f_performance(clf_svr)
# Out:
# ******************
# MSE : 0.040
# RMSE : 0.200
# R2 : 0.962

# %% [markdown]
# ### 4.3.2.Coefficients du modèle

# %%
clf_svr.named_steps['model'].intercept_
# Out:
# array([0.28995021])

# %%
#clf_svr.n_features_in_

# %%
#clf_svr.feature_names_in_

# %% [markdown]
# ### 4.3.3.Optimisation du modèle

# %% [markdown]
# #### Cross validation

# %%
scores = cross_val_score(clf_svr, X, y, cv=10,scoring='r2')#Ajustement-des-param%C3%A8trese(clf_svr, X, y, cv=10,scoring='r2')#coefficient of determination (pr défaut). how well the regression model fits the observed data.a higher coefficient indicates a better fit for the model.
scores
# Out:
# array([0.84637067, 0.9741497 , 0.97924932, 0.97366129, 0.97641573,
#        0.93646731, 0.96152914, 0.9803658 , 0.9787399 , 0.96760626])

# %%
print(" mean of  R2= %0.2f" % scores.mean())
# Out:
#  mean of  R2= 0.96

# %% [markdown]
# #### Ajustement des paramètres

# %%
SVR().get_params().keys()

# %%
param_grid = {
    
    "model__C": [1,0.1,0.01,0.001,0.0001,0.00001,0.00001,2,3,4,5,10],
    "model__epsilon": [0.0001, 0.001, 0.1, 1, 0.005, 0.0009],
    #"model__kernel": [True, False],
    #"model__gamma": [True, False],
    
}

grid_search = GridSearchCV(clf_svr, param_grid, cv=10)
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['%NaturalGas(kBtu)',
#                                                                           '%SteamUse(kBtu)',
#                                                                           'GHGEmissionsIntensity',
#                                                                           'NumberofBuildings',
#                                                                           'GFABuildingRate',
#                                                                           'BuildingAge',
#                                                                           'ENERGYSTARScore',
#                                                                           'NumberofFloors',
#                                                                           'PropertyGFATotal',
#                                                                           'SourceEUI(kBtu/sf)']),
#                                                                         ('cat',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        handle_unknown='ignore'),
#                                                                          ['tranche_date',
#                                                                           'groups_PrimaryPropertyType',
#                                                                           'groups_neighborhood',
#                                                                           'BuildingType'])])),
#                                        ('model', SVR())]),
#              param_grid={'model__C': [1, 0.1, 0.01, 0.001, 0.0001, 1e-05, 1e-05,
#                                       2, 3, 4, 5, 10],
#                          'model__epsilon': [0.0001, 0.001, 0.1, 1, 0.005,
#                                             0.0009]})

# %%
save_model_grid(grid_search,'gridsearch_svr','gridsearch')

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.275522      0.007164         0.033995        0.005552
# 1        0.275024      0.010373         0.031248        0.000004
# 2        0.079691      0.004683         0.014066        0.004689
# 3        0.028143      0.006245         0.000000        0.000000
# 4        0.242196      0.007813         0.032823        0.004683
# ..            ...           ...              ...             ...
# 67       1.251984      0.043230         0.037598        0.001756
# 68       0.086868      0.002938         0.015990        0.001479
# 69       0.029883      0.001757         0.011995        0.002190
# 70       1.014717      0.056832         0.038636        0.006895
# 71       1.289438      0.081481         0.039475        0.003260
#
#    param_model__C param_model__epsilon  \
# 0               1               0.0001
# 1               1                0.001
# 2               1                  0.1
# 3               1                    1
# 4               1                0.005
# ..            ...                  ...
# 67             10                0.001
# 68             10                  0.1
# 69             10                    1
# 70             10                0.005
# 71             10               0.0009
#
#                                         params  split0_test_score  \
# 0    {'model__C': 1, 'model__epsilon': 0.0001}           0.984808
# 1     {'model__C': 1, 'model__epsilon': 0.001}           0.984776
# 2       {'model__C': 1, 'model__epsilon': 0.1}           0.977776
# 3         {'model__C': 1, 'model__epsilon': 1}           0.712322
# 4     {'model__C': 1, 'model__epsilon': 0.005}           0.984692
# ..                                         ...                ...
# 67   {'model__C': 10, 'model__epsilon': 0.001}           0.989647
# 68     {'model__C': 10, 'model__epsilon': 0.1}           0.980059
# 69       {'model__C': 10, 'model__epsilon': 1}           0.736651
# 70   {'model__C': 10, 'model__epsilon': 0.005}           0.989821
# 71  {'model__C': 10, 'model__epsilon': 0.0009}           0.989643
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.967676           0.981833           0.940625
# 1            0.967610           0.981827           0.940588
# 2            0.958733           0.976466           0.932616
# 3            0.730328           0.759564           0.721007
# 4            0.967302           0.981831           0.940457
# ..                ...                ...                ...
# 67           0.987127           0.988577           0.950406
# 68           0.977287           0.979152           0.945265
# 69           0.759490           0.762693           0.727860
# 70           0.986540           0.988686           0.950803
# 71           0.987143           0.988577           0.950398
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 0            0.982530           0.968201           0.963275
# 1            0.982506           0.968158           0.963280
# 2            0.975198           0.955930           0.954055
# 3            0.786761           0.721767           0.680403
# 4            0.982208           0.968030           0.963195
# ..                ...                ...                ...
# 67           0.985988           0.984020           0.965443
# 68           0.978341           0.962994           0.957222
# 69           0.798660           0.728040           0.668186
# 70           0.985961           0.984051           0.965432
# 71           0.985985           0.984003           0.965453
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 0            0.982752           0.972675           0.984724         0.972910
# 1            0.982791           0.972696           0.984702         0.972893
# 2            0.977533           0.962869           0.976933         0.964811
# 3            0.775221           0.704143           0.684161         0.727568
# 4            0.982815           0.972799           0.984533         0.972786
# ..                ...                ...                ...              ...
# 67           0.992297           0.982201           0.983791         0.980950
# 68           0.988833           0.969881           0.979223         0.971826
# 69           0.806278           0.740791           0.695337         0.742399
# 70           0.992239           0.982264           0.984111         0.980991
# 71           0.992299           0.982204           0.983780         0.980949
#
#     std_test_score  rank_test_score
# 0         0.013172               21
# 1         0.013180               23
# 2         0.014115               30
# 3         0.034311               41
# 4         0.013194               24
# ..             ...              ...
# 67        0.012323                2
# 68        0.012403               25
# 69        0.040156               36
# 70        0.012220                1
# 71        0.012324                3
#
# [72 rows x 20 columns]

# %%
grid_search.best_params_
# Out:
# {'model__C': 10, 'model__epsilon': 0.005}

# %%
best_estim=grid_search.best_estimator_
f_performance(best_estim)
# Out:
# ******************
# MSE : 0.028
# RMSE : 0.166
# R2 : 0.974

# %%
save_model_grid(best_estim,'best_SVR','model')

# %%
best_model = grid_search.best_estimator_['model'].fit(X_train_encoded, y_train)
ex = shap.Explainer(best_model.predict, X_train_encoded)
shap_values = ex(X_train_encoded)



shap.summary_plot(shap_values, X_train_encoded,feature_names=feature_after_transformer(preprocessor))
# Out:
# Permutation explainer:   2%|▏         | 20/1232 [02:15<2:00:20,  5.96s/it]

# %%
# fit the preprocessor 
X_encoded = grid_search.best_estimator_['preprocessor'].fit_transform(X_train)

# fit the model 
best_model = grid_search.best_estimator_['model'].fit(X_encoded, y_train)

# calculate the Shap values
shap_values = shap.KernelExplainer(best_model.predict,X_encoded).shap_values(X_encoded)
#Using 1232 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) 
#to summarize the background as K samples.
# Out:
# Using 1232 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1232 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [55], in <cell line: 8>()
#       5 best_model = grid_search.best_estimator_['model'].fit(X_encoded, y_train)
#       7 # calculate the Shap values
# ----> 8 shap_values = shap.KernelExplainer(best_model.predict,X_encoded).shap_values(X_encoded)
#
# File ~\.conda\envs\geo_env\lib\site-packages\shap\explainers\_kernel.py:190, in Kernel.shap_values(self, X, **kwargs)
#     188 if self.keep_index:
#     189     data = convert_to_instance_with_index(data, column_name, index_value[i:i + 1], index_name)
# --> 190 explanations.append(self.explain(data, **kwargs))
#     191 if kwargs.get("gc_collect", False):
#     192     gc.collect()
#
# File ~\.conda\envs\geo_env\lib\site-packages\shap\explainers\_kernel.py:382, in Kernel.explain(self, incoming_instance, **kwargs)
#     379     self.kernelWeights[nfixed_samples:] *= weight_left / self.kernelWeights[nfixed_samples:].sum()
#     381 # execute the model on the synthetic samples we have created
# --> 382 self.run()
#     384 # solve then expand the feature importance (Shapley value) vector to contain the non-varying features
#     385 phi = np.zeros((self.data.groups_size, self.D))
#
# File ~\.conda\envs\geo_env\lib\site-packages\shap\explainers\_kernel.py:521, in Kernel.run(self)
#     519     if self.keep_index_ordered:
#     520         data = data.sort_index()
# --> 521 modelOut = self.model.f(data)
#     522 if isinstance(modelOut, (pd.DataFrame, pd.Series)):
#     523     modelOut = modelOut.values
#
# File ~\.conda\envs\geo_env\lib\site-packages\sklearn\svm\_base.py:416, in BaseLibSVM.predict(self, X)
#     414 X = self._validate_for_predict(X)
#     415 predict = self._sparse_predict if self._sparse else self._dense_predict
# --> 416 return predict(X)
#
# File ~\.conda\envs\geo_env\lib\site-packages\sklearn\svm\_base.py:435, in BaseLibSVM._dense_predict(self, X)
#     427         raise ValueError(
#     428             "X.shape[1] = %d should be equal to %d, "
#     429             "the number of samples at training time"
#     430             % (X.shape[1], self.shape_fit_[0])
#     431         )
#     433 svm_type = LIBSVM_IMPL.index(self._impl)
# --> 435 return libsvm.predict(
#     436     X,
#     437     self.support_,
#     438     self.support_vectors_,
#     439     self._n_support,
#     440     self._dual_coef_,
#     441     self._intercept_,
#     442     self._probA,
#     443     self._probB,
#     444     svm_type=svm_type,
#     445     kernel=kernel,
#     446     degree=self.degree,
#     447     coef0=self.coef0,
#     448     gamma=self._gamma,
#     449     cache_size=self.cache_size,
#     450 )
#
# KeyboardInterrupt:

# %% [markdown]
# ### 4.4.LGBMRegressor

# %%
clf_lgb = Pipeline(
    steps=[("preprocessor", preprocessor), ("model", LGBMRegressor(boosting_type='gbdt',num_leaves=31,max_depth=1))]
)
clf_lgb.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['NumberofBuildings',
#                                                    '%NaturalGas(kBtu)',
#                                                    'NumberofFloors',
#                                                    '%SteamUse(kBtu)',
#                                                    'ENERGYSTARScore',
#                                                    'SourceEUI(kBtu/sf)',
#                                                    'GFABuildingRate',
#                                                    'PropertyGFATotal',
#                                                    'GHGEmissionsIntensity',
#                                                    'BuildingAge']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['groups_PrimaryPropertyType',
#                                                    'BuildingType',
#                                                    'groups_neighborhood',
#                                                    'tranche_date'])])),
#                 ('model', LGBMRegressor(max_depth=1))])

# %% [markdown]
# ### 4.4.1.Indicateurs de performance

# %%
f_performance(clf_lgb)
# Out:
# ******************
# MSE : 0.054
# RMSE : 0.233
# R2 : 0.948

# %% [markdown]
# ### 4.4.2.Optimisation du modèle

# %%
#### Cross validation

# %% [markdown]
# #### Ajustement des paramètres

# %%
list(clf_lgb.get_params().keys())
# Out:
# ['memory',
#  'steps',
#  'verbose',
#  'preprocessor',
#  'model',
#  'preprocessor__n_jobs',
#  'preprocessor__remainder',
#  'preprocessor__sparse_threshold',
#  'preprocessor__transformer_weights',
#  'preprocessor__transformers',
#  'preprocessor__verbose',
#  'preprocessor__verbose_feature_names_out',
#  'preprocessor__num',
#  'preprocessor__cat',
#  'preprocessor__num__memory',
#  'preprocessor__num__steps',
#  'preprocessor__num__verbose',
#  'preprocessor__num__scaler',
#  'preprocessor__num__scaler__copy',
#  'preprocessor__num__scaler__with_mean',
#  'preprocessor__num__scaler__with_std',
#  'preprocessor__cat__categories',
#  'preprocessor__cat__drop',
#  'preprocessor__cat__dtype',
#  'preprocessor__cat__handle_unknown',
#  'preprocessor__cat__sparse',
#  'model__boosting_type',
#  'model__class_weight',
#  'model__colsample_bytree',
#  'model__importance_type',
#  'model__learning_rate',
#  'model__max_depth',
#  'model__min_child_samples',
#  'model__min_child_weight',
#  'model__min_split_gain',
#  'model__n_estimators',
#  'model__n_jobs',
#  'model__num_leaves',
#  'model__objective',
#  'model__random_state',
#  'model__reg_alpha',
#  'model__reg_lambda',
#  'model__silent',
#  'model__subsample',
#  'model__subsample_for_bin',
#  'model__subsample_freq']

# %%
param_grid = {
    
    "model__max_depth": [5,10,20,15,30],
    "model__num_leaves": [150,50,10,20,5,100],
     "model__boosting_type": ['gbdt', 'rbf','dart','goss'],
    "model__learning_rate": [0.1, 0.01,1,0.5,0.6,0.7,0.4],
    
}

grid_search = GridSearchCV(clf_lgb, param_grid, cv=10)
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['NumberofBuildings',
#                                                                           '%NaturalGas(kBtu)',
#                                                                           'NumberofFloors',
#                                                                           '%SteamUse(kBtu)',
#                                                                           'ENERGYSTARScore',
#                                                                           'SourceEUI(kBtu/sf)',
#                                                                           'GFABuildingRate',
#                                                                           'PropertyGFATotal',
#                                                                           'GHGEmissionsIntensity',
#                                                                           'BuildingAge']),
#                                                                         ('cat',
#                                                                          OneHo...irst',
#                                                                                        handle_unknown='ignore'),
#                                                                          ['groups_PrimaryPropertyType',
#                                                                           'BuildingType',
#                                                                           'groups_neighborhood',
#                                                                           'tranche_date'])])),
#                                        ('model', LGBMRegressor(max_depth=1))]),
#              param_grid={'model__boosting_type': ['gbdt', 'rbf', 'dart',
#                                                   'goss'],
#                          'model__learning_rate': [0.1, 0.01, 1, 0.5, 0.6, 0.7,
#                                                   0.4],
#                          'model__max_depth': [5, 10, 20, 15, 30],
#                          'model__num_leaves': [150, 50, 10, 20, 5, 100]})

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.274687      0.029833         0.002480        0.005157
# 1         0.248776      0.011032         0.009904        0.008230
# 2         0.201922      0.014857         0.007815        0.007815
# 3         0.239545      0.015216         0.007813        0.007813
# 4         0.135611      0.009772         0.010367        0.008655
# ..             ...           ...              ...             ...
# 835       0.290651      0.014295         0.006250        0.007655
# 836       0.230999      0.011964         0.003125        0.006250
# 837       0.275866      0.013052         0.007814        0.007814
# 838       0.144609      0.010429         0.010939        0.007161
# 839       0.281000      0.009255         0.010938        0.007161
#
#     param_model__boosting_type param_model__learning_rate  \
# 0                         gbdt                        0.1
# 1                         gbdt                        0.1
# 2                         gbdt                        0.1
# 3                         gbdt                        0.1
# 4                         gbdt                        0.1
# ..                         ...                        ...
# 835                       goss                        0.4
# 836                       goss                        0.4
# 837                       goss                        0.4
# 838                       goss                        0.4
# 839                       goss                        0.4
#
#     param_model__max_depth param_model__num_leaves  \
# 0                        5                     150
# 1                        5                      50
# 2                        5                      10
# 3                        5                      20
# 4                        5                       5
# ..                     ...                     ...
# 835                     30                      50
# 836                     30                      10
# 837                     30                      20
# 838                     30                       5
# 839                     30                     100
#
#                                                 params  split0_test_score  \
# 0    {'model__boosting_type': 'gbdt', 'model__learn...           0.985318
# 1    {'model__boosting_type': 'gbdt', 'model__learn...           0.985318
# 2    {'model__boosting_type': 'gbdt', 'model__learn...           0.984503
# 3    {'model__boosting_type': 'gbdt', 'model__learn...           0.985539
# 4    {'model__boosting_type': 'gbdt', 'model__learn...           0.988914
# ..                                                 ...                ...
# 835  {'model__boosting_type': 'goss', 'model__learn...           0.975304
# 836  {'model__boosting_type': 'goss', 'model__learn...           0.967381
# 837  {'model__boosting_type': 'goss', 'model__learn...           0.974512
# 838  {'model__boosting_type': 'goss', 'model__learn...           0.968199
# 839  {'model__boosting_type': 'goss', 'model__learn...           0.975304
#
#      ...  split3_test_score  split4_test_score  split5_test_score  \
# 0    ...           0.945811           0.989637           0.989021
# 1    ...           0.945811           0.989637           0.989021
# 2    ...           0.940950           0.990562           0.987359
# 3    ...           0.943211           0.990018           0.988954
# 4    ...           0.940431           0.991133           0.985744
# ..   ...                ...                ...                ...
# 835  ...           0.931928           0.978395           0.979133
# 836  ...           0.940841           0.977631           0.972275
# 837  ...           0.927219           0.978649           0.963376
# 838  ...           0.939145           0.980663           0.976198
# 839  ...           0.931928           0.978395           0.979133
#
#      split6_test_score  split7_test_score  split8_test_score  \
# 0             0.990977           0.992188           0.994163
# 1             0.990977           0.992188           0.994163
# 2             0.990956           0.992354           0.993161
# 3             0.991011           0.992452           0.992997
# 4             0.991107           0.990441           0.994503
# ..                 ...                ...                ...
# 835           0.982208           0.987467           0.978073
# 836           0.975643           0.985054           0.967847
# 837           0.976898           0.983434           0.975063
# 838           0.979501           0.984739           0.976847
# 839           0.982208           0.987467           0.978073
#
#      split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.993309         0.985254        0.013474               37
# 1             0.993309         0.985254        0.013474               37
# 2             0.993957         0.984849        0.014927               53
# 3             0.993675         0.985112        0.014228               44
# 4             0.991470         0.984459        0.014994               65
# ..                 ...              ...             ...              ...
# 835           0.979883         0.973880        0.014811              281
# 836           0.969539         0.970499        0.011106              345
# 837           0.974201         0.969640        0.015038              363
# 838           0.975962         0.973368        0.012141              294
# 839           0.979883         0.973880        0.014811              281
#
# [840 rows x 22 columns]

# %%
grid_search.best_params_
# Out:
# {'model__boosting_type': 'dart',
#  'model__learning_rate': 0.4,
#  'model__max_depth': 15,
#  'model__num_leaves': 150}

# %%
best_estim=grid_search.best_estimator_
f_performance(best_estim)
# Out:
# ******************
# MSE : 0.028
# RMSE : 0.168
# R2 : 0.973

# %% [markdown]
# ## 4.5.RandomForestRegressor

# %%
clf_rf = Pipeline(
    steps=[("preprocessor", preprocessor), ("model", RandomForestRegressor(n_estimators=300,max_leaf_nodes=1000,criterion='squared_error'))]
)
clf_rf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['SourceEUI(kBtu/sf)',
#                                                    'NumberofFloors',
#                                                    'BuildingAge',
#                                                    'GHGEmissionsIntensity',
#                                                    'PropertyGFATotal',
#                                                    'NumberofBuildings',
#                                                    'ENERGYSTARScore']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['BuildingType',
#                                                    'tranche_date',
#                                                    'groups_neighborhood',
#                                                    'groups_PrimaryPropertyType'])])),
#                 ('model',
#                  RandomForestRegressor(max_leaf_nodes=1000, n_estimators=300))])

# %% [markdown]
# ### 4.5.1.Indicateurs de performance

# %%
f_performance(clf_rf)
# Out:
# ******************
# MSE : 0.181
# RMSE : 0.425
# R2 : 0.819

# %% [markdown]
# ### 4.5.2.Optimisation du modèle

# %%
list(clf_rf.get_params().keys())
# Out:
# ['memory',
#  'steps',
#  'verbose',
#  'preprocessor',
#  'model',
#  'preprocessor__n_jobs',
#  'preprocessor__remainder',
#  'preprocessor__sparse_threshold',
#  'preprocessor__transformer_weights',
#  'preprocessor__transformers',
#  'preprocessor__verbose',
#  'preprocessor__verbose_feature_names_out',
#  'preprocessor__num',
#  'preprocessor__cat',
#  'preprocessor__num__memory',
#  'preprocessor__num__steps',
#  'preprocessor__num__verbose',
#  'preprocessor__num__scaler',
#  'preprocessor__num__scaler__copy',
#  'preprocessor__num__scaler__with_mean',
#  'preprocessor__num__scaler__with_std',
#  'preprocessor__cat__categories',
#  'preprocessor__cat__drop',
#  'preprocessor__cat__dtype',
#  'preprocessor__cat__handle_unknown',
#  'preprocessor__cat__sparse',
#  'model__bootstrap',
#  'model__ccp_alpha',
#  'model__criterion',
#  'model__max_depth',
#  'model__max_features',
#  'model__max_leaf_nodes',
#  'model__max_samples',
#  'model__min_impurity_decrease',
#  'model__min_samples_leaf',
#  'model__min_samples_split',
#  'model__min_weight_fraction_leaf',
#  'model__n_estimators',
#  'model__n_jobs',
#  'model__oob_score',
#  'model__random_state',
#  'model__verbose',
#  'model__warm_start']

# %%
param_grid = {
    
    "model__max_leaf_nodes": [1000,5000,100000,None],
    "model__n_estimators": [150,50,10,250,100],
     "model__criterion": ['squared_error', 'absolute_error', 'poisson']
    
}
grid_search = GridSearchCV(clf_rf, param_grid, cv=10)
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['SourceEUI(kBtu/sf)',
#                                                                           'NumberofFloors',
#                                                                           'BuildingAge',
#                                                                           'GHGEmissionsIntensity',
#                                                                           'PropertyGFATotal',
#                                                                           'NumberofBuildings',
#                                                                           'ENERGYSTARScore']),
#                                                                         ('cat',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        handle_unknown='ignore'),
#                                                                          ['BuildingType',
#                                                                           'tranche_date',
#                                                                           'groups_neighborhood',
#                                                                           'groups_PrimaryPropertyType'])])),
#                                        ('model',
#                                         RandomForestRegressor(max_leaf_nodes=1000,
#                                                               n_estimators=300))]),
#              param_grid={'model__criterion': ['squared_error', 'absolute_error',
#                                               'poisson'],
#                          'model__max_leaf_nodes': [1000, 5000, 100000, None],
#                          'model__n_estimators': [150, 50, 10, 250, 100]})

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        1.235810      0.051455         0.034659    6.190005e-03
# 1        0.428158      0.017367         0.017189    4.686515e-03
# 2        0.095305      0.004687         0.010952    7.169625e-03
# 3        2.028242      0.027768         0.050011    6.243204e-03
# 4        0.828063      0.051981         0.025001    7.654130e-03
# 5        1.235894      0.022253         0.032812    4.686952e-03
# 6        0.431284      0.028135         0.018751    6.249499e-03
# 7        0.096879      0.006244         0.009375    7.654967e-03
# 8        2.048421      0.062744         0.049998    6.249285e-03
# 9        0.828179      0.027067         0.025000    7.654003e-03
# 10       1.392332      0.022639         0.034375    6.249344e-03
# 11       0.484060      0.025428         0.018752    6.248702e-03
# 12       0.104707      0.010039         0.010937    7.160197e-03
# 13       2.312655      0.044774         0.050012    6.242893e-03
# 14       0.942263      0.040768         0.026563    7.159796e-03
# 15       1.176641      0.026198         0.031250    1.434678e-06
# 16       0.398464      0.007820         0.015627    8.779503e-07
# 17       0.091957      0.004668         0.009376    7.655454e-03
# 18       1.926869      0.041427         0.046874    6.036276e-07
# 19       0.784427      0.022974         0.025000    7.653585e-03
# 20      10.239403      0.117076         0.031266    4.219174e-05
# 21       3.492385      0.147449         0.017190    4.681543e-03
# 22       0.707852      0.024268         0.007814    7.814098e-03
# 23      17.562872      0.965322         0.053389    6.179192e-03
# 24       7.271440      0.328459         0.028596    4.518008e-03
# 25      11.411479      0.379947         0.040832    4.153530e-03
# 26       3.740182      0.402396         0.018298    2.142722e-03
# 27       0.850768      0.104284         0.012295    2.490318e-03
# 28      20.439422      1.411335         0.066763    1.623222e-02
# 29       7.421516      0.658918         0.028486    4.564617e-03
# 30      11.514952      0.828548         0.040682    6.221477e-03
# 31       3.790324      0.191896         0.021187    5.685320e-03
# 32       0.749853      0.011614         0.011296    1.187007e-03
# 33      18.080124      0.757086         0.057524    1.116460e-02
# 34       7.648622      0.278096         0.030434    4.230265e-03
# 35      10.312446      0.443109         0.034582    4.980877e-03
# 36       3.416553      0.040936         0.016990    9.979378e-04
# 37       0.685407      0.009636         0.010095    5.384733e-04
# 38      16.943408      0.193892         0.049072    2.164951e-03
# 39       6.835693      0.056412         0.024587    7.999719e-04
# 40       0.015092      0.002341         0.000000    0.000000e+00
# 41       0.014296      0.000460         0.000000    0.000000e+00
# 42       0.015090      0.000831         0.000000    0.000000e+00
# 43       0.015992      0.000447         0.000000    0.000000e+00
# 44       0.015992      0.000775         0.000000    0.000000e+00
# 45       0.015892      0.000538         0.000000    0.000000e+00
# 46       0.015992      0.000447         0.000000    0.000000e+00
# 47       0.015592      0.000490         0.000000    0.000000e+00
# 48       0.015992      0.000447         0.000000    0.000000e+00
# 49       0.015992      0.000447         0.000000    0.000000e+00
# 50       0.015592      0.000490         0.000000    0.000000e+00
# 51       0.015792      0.000600         0.000000    0.000000e+00
# 52       0.015892      0.000300         0.000000    0.000000e+00
# 53       0.015094      0.000699         0.000000    0.000000e+00
# 54       0.014490      0.000498         0.000000    0.000000e+00
# 55       0.014692      0.000458         0.000000    0.000000e+00
# 56       0.015390      0.001353         0.000000    0.000000e+00
# 57       0.016394      0.000797         0.000000    0.000000e+00
# 58       0.017491      0.001746         0.000000    0.000000e+00
# 59       0.015993      0.001096         0.000000    0.000000e+00
#
#    param_model__criterion param_model__max_leaf_nodes  \
# 0           squared_error                        1000
# 1           squared_error                        1000
# 2           squared_error                        1000
# 3           squared_error                        1000
# 4           squared_error                        1000
# 5           squared_error                        5000
# 6           squared_error                        5000
# 7           squared_error                        5000
# 8           squared_error                        5000
# 9           squared_error                        5000
# 10          squared_error                      100000
# 11          squared_error                      100000
# 12          squared_error                      100000
# 13          squared_error                      100000
# 14          squared_error                      100000
# 15          squared_error                        None
# 16          squared_error                        None
# 17          squared_error                        None
# 18          squared_error                        None
# 19          squared_error                        None
# 20         absolute_error                        1000
# 21         absolute_error                        1000
# 22         absolute_error                        1000
# 23         absolute_error                        1000
# 24         absolute_error                        1000
# 25         absolute_error                        5000
# 26         absolute_error                        5000
# 27         absolute_error                        5000
# 28         absolute_error                        5000
# 29         absolute_error                        5000
# 30         absolute_error                      100000
# 31         absolute_error                      100000
# 32         absolute_error                      100000
# 33         absolute_error                      100000
# 34         absolute_error                      100000
# 35         absolute_error                        None
# 36         absolute_error                        None
# 37         absolute_error                        None
# 38         absolute_error                        None
# 39         absolute_error                        None
# 40                poisson                        1000
# 41                poisson                        1000
# 42                poisson                        1000
# 43                poisson                        1000
# 44                poisson                        1000
# 45                poisson                        5000
# 46                poisson                        5000
# 47                poisson                        5000
# 48                poisson                        5000
# 49                poisson                        5000
# 50                poisson                      100000
# 51                poisson                      100000
# 52                poisson                      100000
# 53                poisson                      100000
# 54                poisson                      100000
# 55                poisson                        None
# 56                poisson                        None
# 57                poisson                        None
# 58                poisson                        None
# 59                poisson                        None
#
#    param_model__n_estimators  \
# 0                        150
# 1                         50
# 2                         10
# 3                        250
# 4                        100
# 5                        150
# 6                         50
# 7                         10
# 8                        250
# 9                        100
# 10                       150
# 11                        50
# 12                        10
# 13                       250
# 14                       100
# 15                       150
# 16                        50
# 17                        10
# 18                       250
# 19                       100
# 20                       150
# 21                        50
# 22                        10
# 23                       250
# 24                       100
# 25                       150
# 26                        50
# 27                        10
# 28                       250
# 29                       100
# 30                       150
# 31                        50
# 32                        10
# 33                       250
# 34                       100
# 35                       150
# 36                        50
# 37                        10
# 38                       250
# 39                       100
# 40                       150
# 41                        50
# 42                        10
# 43                       250
# 44                       100
# 45                       150
# 46                        50
# 47                        10
# 48                       250
# 49                       100
# 50                       150
# 51                        50
# 52                        10
# 53                       250
# 54                       100
# 55                       150
# 56                        50
# 57                        10
# 58                       250
# 59                       100
#
#                                                params  split0_test_score  \
# 0   {'model__criterion': 'squared_error', 'model__...           0.770524
# 1   {'model__criterion': 'squared_error', 'model__...           0.771979
# 2   {'model__criterion': 'squared_error', 'model__...           0.746031
# 3   {'model__criterion': 'squared_error', 'model__...           0.775747
# 4   {'model__criterion': 'squared_error', 'model__...           0.774419
# 5   {'model__criterion': 'squared_error', 'model__...           0.773079
# 6   {'model__criterion': 'squared_error', 'model__...           0.771545
# 7   {'model__criterion': 'squared_error', 'model__...           0.742813
# 8   {'model__criterion': 'squared_error', 'model__...           0.774959
# 9   {'model__criterion': 'squared_error', 'model__...           0.776885
# 10  {'model__criterion': 'squared_error', 'model__...           0.780208
# 11  {'model__criterion': 'squared_error', 'model__...           0.768530
# 12  {'model__criterion': 'squared_error', 'model__...           0.756263
# 13  {'model__criterion': 'squared_error', 'model__...           0.772812
# 14  {'model__criterion': 'squared_error', 'model__...           0.771274
# 15  {'model__criterion': 'squared_error', 'model__...           0.771998
# 16  {'model__criterion': 'squared_error', 'model__...           0.776886
# 17  {'model__criterion': 'squared_error', 'model__...           0.752591
# 18  {'model__criterion': 'squared_error', 'model__...           0.774205
# 19  {'model__criterion': 'squared_error', 'model__...           0.770496
# 20  {'model__criterion': 'absolute_error', 'model_...           0.783277
# 21  {'model__criterion': 'absolute_error', 'model_...           0.766504
# 22  {'model__criterion': 'absolute_error', 'model_...           0.764546
# 23  {'model__criterion': 'absolute_error', 'model_...           0.777930
# 24  {'model__criterion': 'absolute_error', 'model_...           0.785361
# 25  {'model__criterion': 'absolute_error', 'model_...           0.784314
# 26  {'model__criterion': 'absolute_error', 'model_...           0.775248
# 27  {'model__criterion': 'absolute_error', 'model_...           0.773912
# 28  {'model__criterion': 'absolute_error', 'model_...           0.785918
# 29  {'model__criterion': 'absolute_error', 'model_...           0.783255
# 30  {'model__criterion': 'absolute_error', 'model_...           0.787409
# 31  {'model__criterion': 'absolute_error', 'model_...           0.780321
# 32  {'model__criterion': 'absolute_error', 'model_...           0.773095
# 33  {'model__criterion': 'absolute_error', 'model_...           0.779016
# 34  {'model__criterion': 'absolute_error', 'model_...           0.777429
# 35  {'model__criterion': 'absolute_error', 'model_...           0.779640
# 36  {'model__criterion': 'absolute_error', 'model_...           0.779316
# 37  {'model__criterion': 'absolute_error', 'model_...           0.728806
# 38  {'model__criterion': 'absolute_error', 'model_...           0.784645
# 39  {'model__criterion': 'absolute_error', 'model_...           0.778020
# 40  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 41  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 42  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 43  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 44  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 45  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 46  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 47  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 48  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 49  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 50  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 51  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 52  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 53  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 54  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 55  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 56  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 57  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 58  {'model__criterion': 'poisson', 'model__max_le...                NaN
# 59  {'model__criterion': 'poisson', 'model__max_le...                NaN
#
#     split1_test_score  ...  split3_test_score  split4_test_score  \
# 0            0.827315  ...           0.693124           0.794743
# 1            0.826657  ...           0.689270           0.791459
# 2            0.811385  ...           0.674965           0.786020
# 3            0.830181  ...           0.704650           0.792418
# 4            0.834681  ...           0.710001           0.793383
# 5            0.825579  ...           0.701369           0.791862
# 6            0.827661  ...           0.710311           0.785841
# 7            0.814829  ...           0.709604           0.777278
# 8            0.826081  ...           0.699128           0.789415
# 9            0.822717  ...           0.700846           0.792048
# 10           0.823006  ...           0.702718           0.792234
# 11           0.820626  ...           0.685301           0.790555
# 12           0.818684  ...           0.689910           0.784064
# 13           0.825951  ...           0.705949           0.795783
# 14           0.825676  ...           0.713023           0.789365
# 15           0.822259  ...           0.695490           0.794001
# 16           0.816149  ...           0.697058           0.787625
# 17           0.792211  ...           0.700655           0.789089
# 18           0.826727  ...           0.699246           0.794417
# 19           0.821341  ...           0.695590           0.792971
# 20           0.827209  ...           0.717554           0.793637
# 21           0.820059  ...           0.723826           0.787954
# 22           0.809805  ...           0.713581           0.764606
# 23           0.825252  ...           0.723486           0.788859
# 24           0.830173  ...           0.715522           0.784018
# 25           0.823036  ...           0.732637           0.788105
# 26           0.822189  ...           0.719891           0.783203
# 27           0.815104  ...           0.671756           0.758782
# 28           0.825018  ...           0.719523           0.788077
# 29           0.825433  ...           0.719997           0.786162
# 30           0.827847  ...           0.724124           0.784043
# 31           0.823882  ...           0.709231           0.800551
# 32           0.818975  ...           0.671287           0.761761
# 33           0.823009  ...           0.719235           0.788979
# 34           0.827830  ...           0.715299           0.778409
# 35           0.825838  ...           0.723768           0.787658
# 36           0.828547  ...           0.708090           0.775062
# 37           0.810290  ...           0.721835           0.747193
# 38           0.827149  ...           0.717331           0.787221
# 39           0.817343  ...           0.714312           0.784645
# 40                NaN  ...                NaN                NaN
# 41                NaN  ...                NaN                NaN
# 42                NaN  ...                NaN                NaN
# 43                NaN  ...                NaN                NaN
# 44                NaN  ...                NaN                NaN
# 45                NaN  ...                NaN                NaN
# 46                NaN  ...                NaN                NaN
# 47                NaN  ...                NaN                NaN
# 48                NaN  ...                NaN                NaN
# 49                NaN  ...                NaN                NaN
# 50                NaN  ...                NaN                NaN
# 51                NaN  ...                NaN                NaN
# 52                NaN  ...                NaN                NaN
# 53                NaN  ...                NaN                NaN
# 54                NaN  ...                NaN                NaN
# 55                NaN  ...                NaN                NaN
# 56                NaN  ...                NaN                NaN
# 57                NaN  ...                NaN                NaN
# 58                NaN  ...                NaN                NaN
# 59                NaN  ...                NaN                NaN
#
#     split5_test_score  split6_test_score  split7_test_score  \
# 0            0.854187           0.774557           0.774623
# 1            0.848125           0.765537           0.767325
# 2            0.818058           0.754737           0.754133
# 3            0.850576           0.775838           0.773812
# 4            0.850772           0.765663           0.762001
# 5            0.850841           0.770967           0.775633
# 6            0.848384           0.760372           0.763141
# 7            0.831094           0.762883           0.761612
# 8            0.851055           0.770582           0.771927
# 9            0.851775           0.775123           0.776099
# 10           0.847581           0.768862           0.772085
# 11           0.852087           0.771461           0.776359
# 12           0.822538           0.755178           0.756055
# 13           0.849902           0.780362           0.772394
# 14           0.849390           0.767258           0.779736
# 15           0.849372           0.773797           0.763926
# 16           0.849430           0.772522           0.765090
# 17           0.847335           0.755686           0.761117
# 18           0.852536           0.772845           0.770270
# 19           0.850308           0.772608           0.775632
# 20           0.852014           0.763703           0.766770
# 21           0.846009           0.766090           0.766650
# 22           0.839450           0.748017           0.735770
# 23           0.850349           0.767682           0.769617
# 24           0.848116           0.774156           0.760721
# 25           0.850210           0.766907           0.767982
# 26           0.850286           0.763545           0.761859
# 27           0.829489           0.748866           0.748145
# 28           0.850405           0.768516           0.764731
# 29           0.849941           0.779747           0.758860
# 30           0.851138           0.772609           0.766921
# 31           0.845569           0.762201           0.763501
# 32           0.809603           0.714173           0.739854
# 33           0.851771           0.767140           0.768107
# 34           0.844854           0.770079           0.765960
# 35           0.852730           0.771083           0.764329
# 36           0.849745           0.773501           0.763411
# 37           0.821716           0.748191           0.762353
# 38           0.850474           0.767796           0.762903
# 39           0.853045           0.773581           0.758200
# 40                NaN                NaN                NaN
# 41                NaN                NaN                NaN
# 42                NaN                NaN                NaN
# 43                NaN                NaN                NaN
# 44                NaN                NaN                NaN
# 45                NaN                NaN                NaN
# 46                NaN                NaN                NaN
# 47                NaN                NaN                NaN
# 48                NaN                NaN                NaN
# 49                NaN                NaN                NaN
# 50                NaN                NaN                NaN
# 51                NaN                NaN                NaN
# 52                NaN                NaN                NaN
# 53                NaN                NaN                NaN
# 54                NaN                NaN                NaN
# 55                NaN                NaN                NaN
# 56                NaN                NaN                NaN
# 57                NaN                NaN                NaN
# 58                NaN                NaN                NaN
# 59                NaN                NaN                NaN
#
#     split8_test_score  split9_test_score  mean_test_score  std_test_score  \
# 0            0.801739           0.786490         0.787243        0.039843
# 1            0.802081           0.782436         0.782573        0.040054
# 2            0.792312           0.751151         0.764870        0.038809
# 3            0.807358           0.784881         0.788157        0.036809
# 4            0.805934           0.778287         0.786807        0.037440
# 5            0.807113           0.784880         0.787313        0.037325
# 6            0.798309           0.789374         0.784443        0.035910
# 7            0.789349           0.750571         0.769871        0.033441
# 8            0.806884           0.784643         0.785883        0.037942
# 9            0.807875           0.782563         0.786461        0.037153
# 10           0.802370           0.783823         0.787087        0.036141
# 11           0.794403           0.783987         0.782891        0.040392
# 12           0.790215           0.762322         0.767024        0.037348
# 13           0.804421           0.787377         0.787865        0.035897
# 14           0.804471           0.791190         0.786981        0.034572
# 15           0.809803           0.788850         0.786444        0.038822
# 16           0.808667           0.776857         0.783626        0.037535
# 17           0.805249           0.769082         0.772866        0.036880
# 18           0.807094           0.790513         0.787531        0.038323
# 19           0.806765           0.789951         0.786523        0.038198
# 20           0.800954           0.789838         0.788657        0.034457
# 21           0.799632           0.787908         0.784908        0.031562
# 22           0.801011           0.750651         0.768304        0.035804
# 23           0.804181           0.789859         0.788804        0.032491
# 24           0.797623           0.785325         0.786902        0.034193
# 25           0.798022           0.790473         0.788771        0.030210
# 26           0.808353           0.790560         0.786152        0.033976
# 27           0.775158           0.782573         0.766726        0.040510
# 28           0.806392           0.790840         0.789440        0.033546
# 29           0.804010           0.787780         0.788233        0.033260
# 30           0.807287           0.791083         0.790016        0.032699
# 31           0.800649           0.778132         0.785457        0.035338
# 32           0.785132           0.767779         0.761533        0.041647
# 33           0.802621           0.791364         0.787411        0.033439
# 34           0.806322           0.792834         0.786179        0.033865
# 35           0.797929           0.790495         0.787405        0.032894
# 36           0.799172           0.791753         0.784487        0.036129
# 37           0.787700           0.755445         0.765732        0.031187
# 38           0.801906           0.791276         0.787905        0.034182
# 39           0.804419           0.780966         0.785343        0.034609
# 40                NaN                NaN              NaN             NaN
# 41                NaN                NaN              NaN             NaN
# 42                NaN                NaN              NaN             NaN
# 43                NaN                NaN              NaN             NaN
# 44                NaN                NaN              NaN             NaN
# 45                NaN                NaN              NaN             NaN
# 46                NaN                NaN              NaN             NaN
# 47                NaN                NaN              NaN             NaN
# 48                NaN                NaN              NaN             NaN
# 49                NaN                NaN              NaN             NaN
# 50                NaN                NaN              NaN             NaN
# 51                NaN                NaN              NaN             NaN
# 52                NaN                NaN              NaN             NaN
# 53                NaN                NaN              NaN             NaN
# 54                NaN                NaN              NaN             NaN
# 55                NaN                NaN              NaN             NaN
# 56                NaN                NaN              NaN             NaN
# 57                NaN                NaN              NaN             NaN
# 58                NaN                NaN              NaN             NaN
# 59                NaN                NaN              NaN             NaN
#
#     rank_test_score
# 0                14
# 1                32
# 2                39
# 3                 7
# 4                18
# 5                13
# 6                29
# 7                34
# 8                24
# 9                20
# 10               15
# 11               31
# 12               36
# 13                9
# 14               16
# 15               21
# 16               30
# 17               33
# 18               10
# 19               19
# 20                5
# 21               27
# 22               35
# 23                3
# 24               17
# 25                4
# 26               23
# 27               37
# 28                2
# 29                6
# 30                1
# 31               25
# 32               40
# 33               11
# 34               22
# 35               12
# 36               28
# 37               38
# 38                8
# 39               26
# 40               57
# 41               56
# 42               55
# 43               50
# 44               54
# 45               53
# 46               52
# 47               51
# 48               59
# 49               49
# 50               41
# 51               48
# 52               47
# 53               46
# 54               45
# 55               44
# 56               43
# 57               42
# 58               58
# 59               60
#
# [60 rows x 21 columns]

# %%
grid_search.best_params_
# Out:
# {'model__criterion': 'absolute_error',
#  'model__max_leaf_nodes': 100000,
#  'model__n_estimators': 150}

# %%
best_estim=grid_search.best_estimator_
f_performance(best_estim)
# Out:
# ******************
# MSE : 0.178
# RMSE : 0.422
# R2 : 0.822

# %% [markdown]
# ## 4.6.XGBRegressor

# %%
clf_xg = Pipeline(
    steps=[("preprocessor", preprocessor), ("model", XGBRegressor(objective ='reg:squarederror',
                  n_estimators = 10, seed = 123))]
)
clf_xg.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['SourceEUI(kBtu/sf)',
#                                                    'NumberofFloors',
#                                                    'BuildingAge',
#                                                    'GHGEmissionsIntensity',
#                                                    'PropertyGFATotal',
#                                                    'NumberofBuildings',
#                                                    'ENERGYSTARScore']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['BuildingType',
#                                                    'tranche_date',
#                                                    'groups...
#                               gamma=0, gpu_id=-1, grow_policy='depthwise',
#                               importance_type=None, interaction_constraints='',
#                               learning_rate=0.300000012, max_bin=256,
#                               max_cat_to_onehot=4, max_delta_step=0,
#                               max_depth=6, max_leaves=0, min_child_weight=1,
#                               missing=nan, monotone_constraints='()',
#                               n_estimators=10, n_jobs=0, num_parallel_tree=1,
#                               predictor='auto', random_state=123, reg_alpha=0,
#                               reg_lambda=1, ...))])

# %% [markdown]
# ### 4.6.1.Indicateurs de performance

# %%
f_performance(clf_xg)
# Out:
# ******************
# MSE : 0.181
# RMSE : 0.426
# R2 : 0.819

# %% [markdown]
# ### 4.6.2.Optimisation du modèle

# %%
list(clf_xg.get_params().keys())
# Out:
# ['memory',
#  'steps',
#  'verbose',
#  'preprocessor',
#  'model',
#  'preprocessor__n_jobs',
#  'preprocessor__remainder',
#  'preprocessor__sparse_threshold',
#  'preprocessor__transformer_weights',
#  'preprocessor__transformers',
#  'preprocessor__verbose',
#  'preprocessor__verbose_feature_names_out',
#  'preprocessor__num',
#  'preprocessor__cat',
#  'preprocessor__num__memory',
#  'preprocessor__num__steps',
#  'preprocessor__num__verbose',
#  'preprocessor__num__scaler',
#  'preprocessor__num__scaler__copy',
#  'preprocessor__num__scaler__with_mean',
#  'preprocessor__num__scaler__with_std',
#  'preprocessor__cat__categories',
#  'preprocessor__cat__drop',
#  'preprocessor__cat__dtype',
#  'preprocessor__cat__handle_unknown',
#  'preprocessor__cat__sparse',
#  'model__objective',
#  'model__base_score',
#  'model__booster',
#  'model__callbacks',
#  'model__colsample_bylevel',
#  'model__colsample_bynode',
#  'model__colsample_bytree',
#  'model__early_stopping_rounds',
#  'model__enable_categorical',
#  'model__eval_metric',
#  'model__gamma',
#  'model__gpu_id',
#  'model__grow_policy',
#  'model__importance_type',
#  'model__interaction_constraints',
#  'model__learning_rate',
#  'model__max_bin',
#  'model__max_cat_to_onehot',
#  'model__max_delta_step',
#  'model__max_depth',
#  'model__max_leaves',
#  'model__min_child_weight',
#  'model__missing',
#  'model__monotone_constraints',
#  'model__n_estimators',
#  'model__n_jobs',
#  'model__num_parallel_tree',
#  'model__predictor',
#  'model__random_state',
#  'model__reg_alpha',
#  'model__reg_lambda',
#  'model__sampling_method',
#  'model__scale_pos_weight',
#  'model__subsample',
#  'model__tree_method',
#  'model__validate_parameters',
#  'model__verbosity',
#  'model__seed']

# %%
param = {"booster":"gblinear", "objective":"reg:linear"}
clf_test = Pipeline(
    steps=[("preprocessor", preprocessor), ("model", XGBRegressor(objective ='reg:squarederror',booster="dart",
                  n_estimators = 100))]
)
clf_test.fit(X_train,y_train)
f_performance(clf_test)
# Out:
# ******************
# MSE : 0.177
# RMSE : 0.421
# R2 : 0.823

# %%
param_grid = {
    
    "model__booster": ['squarederror','gbtree'],
    "model__n_estimators": [150,50,10,20,500,100,5],
    
    "model__max_leaves": [10000, 100000,1000,100],
    "model__learning_rate": [0.3, 0.5,0.1,0.01,0.001]
    
}

grid_search = GridSearchCV(clf_xg, param_grid, cv=10)
grid_search.fit(X_train,y_train)
# Out:
# [16:27:39] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:40] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:27:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# ...
# [16:37:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:42] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:47] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:48] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:48] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:48] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:48] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:48] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:49] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:49] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:49] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:49] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:49] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:49] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:49] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:49] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:49] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:49] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:49] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:50] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:50] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:50] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:50] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:50] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:50] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:50] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:50] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:50] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:51] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:52] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:54] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:56] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:58] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:59] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:01] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:03] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:05] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:06] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:08] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:09] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:09] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:09] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:10] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:10] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:10] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:11] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:11] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:38:13] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['SourceEUI(kBtu/sf)',
#                                                                           'NumberofFloors',
#                                                                           'BuildingAge',
#                                                                           'GHGEmissionsIntensity',
#                                                                           'PropertyGFATotal',
#                                                                           'NumberofBuildings',
#                                                                           'ENERGYSTARScore']),
#                                                                         ('cat',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        handle_unknown='ignore'),
#                                                                          ['Buildin...
#                                                      missing=nan,
#                                                      monotone_constraints='()',
#                                                      n_estimators=10, n_jobs=0,
#                                                      num_parallel_tree=1,
#                                                      objective='reg:linear',
#                                                      predictor='auto',
#                                                      random_state=123,
#                                                      reg_alpha=0, ...))]),
#              param_grid={'model__booster': ['squarederror', 'gbtree'],
#                          'model__learning_rate': [0.3, 0.5, 0.1, 0.01, 0.001],
#                          'model__max_leaves': [10000, 100000, 1000, 100],
#                          'model__n_estimators': [150, 50, 10, 20, 500, 100, 5]})

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
grid_search.best_params_
best_estim=grid_search.best_estimator_
f_performance(best_estim)
# Out:
# ******************
# MSE : 0.176
# RMSE : 0.420
# R2 : 0.824
